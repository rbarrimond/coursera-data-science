# %% [markdown]
# # My Jupyter Notebook on IBM Data Science Experience

# %% [markdown]
# __Robert Barrimond__
# Data Science Social Entrepreneur

# %% [markdown]
# I'm interested in data science to help my community be successful entrepreneurs and promote generational wealth.

# %% [markdown]
# The following Python code sets two variables x and y to 5 and 7 respectively. It then calculates the the expression "x to the y power" and displays the result: 78,125.

# %%
x = 5
y = 7
x ** y
# Out:
# 78125

# %% [markdown]
# ---
# * Item
# * Another Item
# * And Another Item
#
# ---
# 1. First
# 2. Second
# 3. Third
# ---
# ![Google Pic](https://www.google.com/images/branding/googlelogo/2x/googlelogo_color_272x92dp.png "Google Pic on Fleek")
#
# ---
# ```Java
# public class ExampleClass implements Runnable {
#
#     public void run() {
#
#         System.out.println("I'm a runnin'!");
#
#     }
# }
# ```
# ---
#
# - [x] Mic drop
# - [x] Aced this assignment
# ---
# [Google](https://www.google.com)
